# %% [markdown]
# ### Project 4: Build a recommendation algorithm based on user listening data from Autoscrobbler
#
# Based on code from here: https://github.com/amironoff/AdvancedSparkAnalytics/blob/master/AdvancedAnalytics.Ch3.py

# %%
# import modules
import os

from pyspark import SparkContext
from pyspark import SparkConf
from pyspark.mllib import recommendation
from pyspark.mllib.recommendation import *

# %%
# set configurations
conf = SparkConf().setMaster("local").setAppName("autoscrobbler")

# %%
# set context
sc = SparkContext.getOrCreate(conf=conf)

# %%
# pathing and params
dir_data = '/data/'

user_artist_data_file = 'user_artist_data.txt'
artist_data_file = 'artist_data.txt'
artist_alias_data_file  = 'artist_alias.txt'

user_artist_full_path = os.path.join('data/',user_artist_data_file)
artist_full_path = os.path.join('data/',artist_data_file)
artist_alias_full_path = os.path.join('data/',artist_alias_data_file)

numPartitions = 2
topk = 10

# %%
# read user_artist_data_file into RDD (417MB file, 24MM records of users’ plays of artists, along with count)
# specifically, each row holds: userID, artistID, count
rawDataRDD = sc.textFile(user_artist_full_path, numPartitions)
rawDataRDD.cache()
rawDataRDD.take(3)
# Out:
# [u'1000002 1 55', u'1000002 1000006 33', u'1000002 1000007 8']

# %%
# read artist_data_file
rawArtistRDD = sc.textFile(artist_full_path)

# %%
# read artist_alias_data_file
rawAliasRDD = sc.textFile(artist_alias_full_path)

# %%
print(rawDataRDD.take(10))
# Out:
# [u'1000002 1 55', u'1000002 1000006 33', u'1000002 1000007 8', u'1000002 1000009 144', u'1000002 1000010 314', u'1000002 1000013 8', u'1000002 1000014 42', u'1000002 1000017 69', u'1000002 1000024 329', u'1000002 1000025 1']

# %%
print(rawArtistRDD.take(10))
# Out:
# [u'1134999\t06Crazy Life', u'6821360\tPang Nakarin', u'10113088\tTerfel, Bartoli- Mozart: Don', u'10151459\tThe Flaming Sidebur', u'6826647\tBodenstandig 3000', u'10186265\tJota Quest e Ivete Sangalo', u'6828986\tToto_XX (1977', u'10236364\tU.S Bombs -', u'1135000\tartist formaly know as Mat', u'10299728\tKassierer - Musik f\xfcr beide Ohren']

# %%
def parseArtistIdNamePair(singlePair):
   splitPair = singlePair.rsplit('\t')
   # we should have two items in the list - id and name of the artist.
   if len(splitPair) != 2:
       #print singlePair
       return []
   else:
       try:
           return [(int(splitPair[0]), splitPair[1])]
       except:
           return []

# %%
artistByID = dict(rawArtistRDD.flatMap(lambda x: parseArtistIdNamePair(x)).collect())

# %%
artist_vals = artistByID.values()

# %%
# print topk values from artistById
artist_vals[:topk]
# Out:
# [u'DJ Tiesto -  P.O.S',
#  u'Air',
#  u'Severed Heads',
#  u'Marianne Faithfull',
#  u'Peace Orchestra',
#  u'Gallon Drunk',
#  u'DJ Tiesto - Solid Globe',
#  u'Omni Trio',
#  u'The Last Poets',
#  u'Rhythm & Sound']

# %%
def parseArtistAlias(alias):
    splitPair = alias.rsplit('\t')
    # we should have two items in the list - id and name of the artist.
    if len(splitPair) != 2:
        #print singlePair
        return []
    else:
        try:
            return [(int(splitPair[0]), int(splitPair[1]))]
        except:
            return []

# %%
artistAlias = rawAliasRDD.flatMap(lambda x: parseArtistAlias(x)).collectAsMap()

# %%
# turn the artistAlias into a broadcast variable.
# This will distribute it to worker nodes efficiently, so we save bandwidth.
artistAliasBroadcast = sc.broadcast(artistAlias)

# %%
artistAliasBroadcast.value.get(2097174)
# Out:
# 1007797

# %%
# Print the number of records from the largest RDD, rawDataRDD
rawDataRDD.count()
# Out:
# 24296858

# %%
# Sample 10% of rawDataRDD using seed 314, to reduce runtime. Call it sample.
weights = [.1, .9]
seed = 314
sample, someOtherJunk = rawDataRDD.randomSplit(weights, seed)
sample.cache()
# Out:
# PythonRDD[12] at RDD at PythonRDD.scala:43

# %%
# take the first 5 records from the sample. each row represents userID, artistID, count.
sample.take(5)
# Out:
# [u'1000002 1000007 8',
#  u'1000002 1000055 25',
#  u'1000002 1000107 4',
#  u'1000002 1000113 30',
#  u'1000002 1000157 2']

# %%
# Based on sampled data, build the matrix for model training
def mapSingleObservation(x):
    # Returns Rating object represented as (user, product, rating) tuple.
    userID, artistID, count = map(lambda lineItem: int(lineItem), x.split())
    # [add line of code here to split each record into userID, artistID, count]
    # given possible aliasing, get finalArtistID
    finalArtistID = artistAliasBroadcast.value.get(artistID)
    if finalArtistID is None:
        finalArtistID = artistID
    return Rating(userID, finalArtistID, count)

# %%
trainData = sample.map(lambda x: mapSingleObservation(x))
trainData.cache()
# Out:
# PythonRDD[14] at RDD at PythonRDD.scala:43

# %%
# Take the first 5 records from trainData
trainData.take(5)
# Out:
# [Rating(user=1000002, product=1000007, rating=8.0),
#  Rating(user=1000002, product=1000055, rating=25.0),
#  Rating(user=1000002, product=1000107, rating=4.0),
#  Rating(user=1000002, product=1000113, rating=30.0),
#  Rating(user=1000002, product=1000157, rating=2.0)]

# %%
# filter trainData, collecting all records where rating = 8.0
trainData.filter(lambda x: x[2] == 8.0).collect()
# Out:
# [Rating(user=1000002, product=1000007, rating=8.0),
#  Rating(user=1000002, product=1001646, rating=8.0),
#  Rating(user=1000002, product=1187, rating=8.0),
#  Rating(user=1000019, product=1001236, rating=8.0),
#  Rating(user=1000022, product=1000038, rating=8.0),
#  Rating(user=1000022, product=1000199, rating=8.0),
#  Rating(user=1000022, product=1000631, rating=8.0),
#  Rating(user=1000028, product=1003465, rating=8.0),
#  Rating(user=1000029, product=1000577, rating=8.0),
#  Rating(user=1000035, product=1001174, rating=8.0),
#  Rating(user=1000035, product=1259, rating=8.0),
#  Rating(user=1000035, product=1478, rating=8.0),
#  Rating(user=1000039, product=1003035, rating=8.0),
#  Rating(user=1000041, product=1295531, rating=8.0),
#  Rating(user=1000047, product=9918732, rating=8.0),
#  Rating(user=1000056, product=1001278, rating=8.0),
#  Rating(user=1000058, product=1003258, rating=8.0),
#  Rating(user=1000060, product=1003827, rating=8.0),
#  Rating(user=1000067, product=1284202, rating=8.0),
#  Rating(user=1000088, product=1004570, rating=8.0),
#  Rating(user=1000091, product=1079732, rating=8.0),
#  Rating(user=1000095, product=1043467, rating=8.0),
#  Rating(user=1000096, product=1014421, rating=8.0),
#  Rating(user=1000098, product=1105979, rating=8.0),
#  Rating(user=1000098, product=4496, rating=8.0),
#  Rating(user=1000099, product=1006371, rating=8.0),
#  Rating(user=1000104, product=118, rating=8.0),
#  Rating(user=1000105, product=1007646, rating=8.0),
#  Rating(user=1000105, product=733, rating=8.0),
#  Rating(user=1000108, product=234, rating=8.0),
#  Rating(user=1000108, product=813, rating=8.0),
#  Rating(user=1000109, product=4392, rating=8.0),
#  Rating(user=1000111, product=1007260, rating=8.0),
#  Rating(user=1000111, product=688, rating=8.0),
#  Rating(user=1000117, product=1002912, rating=8.0),
#  Rating(user=1000127, product=1007445, rating=8.0),
#  Rating(user=1000129, product=1000343, rating=8.0),
#  Rating(user=1000129, product=1632, rating=8.0),
#  Rating(user=1000131, product=1007075, rating=8.0),
#  Rating(user=1000131, product=508, rating=8.0),
#  Rating(user=1000131, product=70, rating=8.0),
#  Rating(user=1000140, product=1057034, rating=8.0),
#  Rating(user=1000143, product=189, rating=8.0),
#  Rating(user=1000151, product=1015157, rating=8.0),
#  Rating(user=1000151, product=202, rating=8.0),
#  Rating(user=1000151, product=677, rating=8.0),
#  Rating(user=1000154, product=1012271, rating=8.0),
#  Rating(user=1000166, product=1003156, rating=8.0),
#  Rating(user=1000166, product=1014649, rating=8.0),
#  Rating(user=1000166, product=9965528, rating=8.0),
#  Rating(user=1000171, product=1000781, rating=8.0),
#  Rating(user=1000171, product=1007045, rating=8.0),
#  Rating(user=1000176, product=1252797, rating=8.0),
#  Rating(user=1000176, product=191, rating=8.0),
#  Rating(user=1000176, product=2022313, rating=8.0),
#  Rating(user=1000177, product=40, rating=8.0),
#  Rating(user=1000178, product=1233130, rating=8.0),
#  Rating(user=1000178, product=1301399, rating=8.0),
#  Rating(user=1000180, product=1000790, rating=8.0),
#  Rating(user=1000180, product=1002587, rating=8.0),
#  Rating(user=1000180, product=1002606, rating=8.0),
#  Rating(user=1000180, product=1011565, rating=8.0),
#  Rating(user=1000180, product=1028225, rating=8.0),
#  Rating(user=1000180, product=1036385, rating=8.0),
#  Rating(user=1000180, product=3287, rating=8.0),
#  Rating(user=1000189, product=1004274, rating=8.0),
#  Rating(user=1000199, product=1001804, rating=8.0),
#  Rating(user=1000199, product=1015918, rating=8.0),
#  Rating(user=1000199, product=1019730, rating=8.0),
#  Rating(user=1000199, product=1244362, rating=8.0),
#  Rating(user=1000199, product=2003, rating=8.0),
#  Rating(user=1000199, product=2103, rating=8.0),
#  Rating(user=1000199, product=678, rating=8.0),
#  Rating(user=1000200, product=1000624, rating=8.0),
#  Rating(user=1000200, product=1002457, rating=8.0),
#  Rating(user=1000200, product=1038, rating=8.0),
#  Rating(user=1000201, product=1003159, rating=8.0),
#  Rating(user=1000201, product=1038918, rating=8.0),
#  Rating(user=1000202, product=1233217, rating=8.0),
#  Rating(user=1000206, product=1233083, rating=8.0),
#  Rating(user=1000208, product=1241005, rating=8.0),
#  Rating(user=1000215, product=1009080, rating=8.0),
#  Rating(user=1000215, product=1369, rating=8.0),
#  Rating(user=1000215, product=70, rating=8.0),
#  Rating(user=1000217, product=1029413, rating=8.0),
#  Rating(user=1000225, product=300, rating=8.0),
#  Rating(user=1000227, product=1009389, rating=8.0),
#  Rating(user=1000231, product=1003926, rating=8.0),
#  Rating(user=1000231, product=1022377, rating=8.0),
#  Rating(user=1000231, product=6645271, rating=8.0),
#  Rating(user=1000239, product=1003730, rating=8.0),
#  Rating(user=1000239, product=1027559, rating=8.0),
#  Rating(user=1000239, product=1053902, rating=8.0),
#  Rating(user=1000239, product=1054541, rating=8.0),
#  Rating(user=1000239, product=1261700, rating=8.0),
#  Rating(user=1000239, product=1770, rating=8.0),
#  Rating(user=1000241, product=1289, rating=8.0),
#  Rating(user=1000246, product=739, rating=8.0),
#  Rating(user=1000246, product=827, rating=8.0),
#  Rating(user=1000248, product=2074054, rating=8.0),
#  Rating(user=1000251, product=1234116, rating=8.0),
#  Rating(user=1000251, product=1240266, rating=8.0),
#  Rating(user=1000261, product=1013551, rating=8.0),
#  Rating(user=1000265, product=1023376, rating=8.0),
#  Rating(user=1000267, product=4623, rating=8.0),
#  Rating(user=1000272, product=751, rating=8.0),
#  Rating(user=1000282, product=1011179, rating=8.0),
#  Rating(user=1000282, product=4531, rating=8.0),
#  Rating(user=1000282, product=478, rating=8.0),
#  Rating(user=1000286, product=1236344, rating=8.0),
#  Rating(user=1000288, product=1006076, rating=8.0),
#  Rating(user=1000288, product=1011038, rating=8.0),
#  Rating(user=1000288, product=1145952, rating=8.0),
#  Rating(user=1000288, product=227, rating=8.0),
#  Rating(user=1000302, product=1001779, rating=8.0),
#  Rating(user=1000305, product=2645, rating=8.0),
#  Rating(user=1000308, product=1158916, rating=8.0),
#  Rating(user=1000327, product=1010149, rating=8.0),
#  Rating(user=1000346, product=1000932, rating=8.0),
#  Rating(user=1000346, product=1001174, rating=8.0),
#  Rating(user=1000346, product=1001295, rating=8.0),
#  Rating(user=1000346, product=1002009, rating=8.0),
#  Rating(user=1000346, product=1004207, rating=8.0),
#  Rating(user=1000346, product=1012754, rating=8.0),
#  Rating(user=1000346, product=1013009, rating=8.0),
#  Rating(user=1000346, product=5477, rating=8.0),
#  Rating(user=1000346, product=705, rating=8.0),
#  Rating(user=1000347, product=2651, rating=8.0),
#  Rating(user=1000349, product=1307, rating=8.0),
#  Rating(user=1000352, product=1009256, rating=8.0),
#  Rating(user=1000352, product=1010695, rating=8.0),
#  Rating(user=1000352, product=1204, rating=8.0),
#  Rating(user=1000352, product=5602, rating=8.0),
#  Rating(user=1000353, product=1269, rating=8.0),
#  Rating(user=1000355, product=1000099, rating=8.0),
#  Rating(user=1000356, product=1000088, rating=8.0),
#  Rating(user=1000356, product=1259, rating=8.0),
#  Rating(user=1000365, product=1031054, rating=8.0),
#  Rating(user=1000368, product=1000156, rating=8.0),
#  Rating(user=1000368, product=1007614, rating=8.0),
#  Rating(user=1000375, product=1003480, rating=8.0),
#  Rating(user=1000375, product=328, rating=8.0),
#  Rating(user=1000376, product=1001529, rating=8.0),
#  Rating(user=1000381, product=930, rating=8.0),
#  Rating(user=1000386, product=2978, rating=8.0),
#  Rating(user=1000387, product=1246277, rating=8.0),
#  Rating(user=1000387, product=816, rating=8.0),
#  Rating(user=1000390, product=1230968, rating=8.0),
#  Rating(user=1000390, product=15, rating=8.0),
#  Rating(user=1000395, product=1022701, rating=8.0),
#  Rating(user=1000395, product=1205, rating=8.0),
#  Rating(user=1000395, product=1292491, rating=8.0),
#  Rating(user=1000395, product=3554, rating=8.0),
#  Rating(user=1000395, product=4786, rating=8.0),
#  Rating(user=1000412, product=1000088, rating=8.0),
#  Rating(user=1000416, product=1035225, rating=8.0),
#  Rating(user=1000416, product=1275996, rating=8.0),
#  Rating(user=1000416, product=891, rating=8.0),
#  Rating(user=1000420, product=1032597, rating=8.0),
#  Rating(user=1000422, product=1275996, rating=8.0),
#  Rating(user=1000443, product=1020773, rating=8.0),
#  Rating(user=1000446, product=1002912, rating=8.0),
#  Rating(user=1000446, product=1006351, rating=8.0),
#  Rating(user=1000446, product=1008074, rating=8.0),
#  Rating(user=1000446, product=1008557, rating=8.0),
#  Rating(user=1000454, product=1035140, rating=8.0),
#  Rating(user=1000454, product=3950, rating=8.0),
#  Rating(user=1000463, product=1056510, rating=8.0),
#  Rating(user=1000471, product=1082668, rating=8.0),
#  Rating(user=1000471, product=1196, rating=8.0),
#  Rating(user=1000472, product=386, rating=8.0),
#  Rating(user=1000475, product=1034259, rating=8.0),
#  Rating(user=1000478, product=313, rating=8.0),
#  Rating(user=1000488, product=1005939, rating=8.0),
#  Rating(user=1000516, product=6873408, rating=8.0),
#  Rating(user=1000518, product=1000130, rating=8.0),
#  Rating(user=1000518, product=121, rating=8.0),
#  Rating(user=1000523, product=2140662, rating=8.0),
#  Rating(user=1000524, product=1967, rating=8.0),
#  Rating(user=1000528, product=83, rating=8.0),
#  Rating(user=1000534, product=3402, rating=8.0),
#  Rating(user=1000544, product=1004641, rating=8.0),
#  Rating(user=1000544, product=1233245, rating=8.0),
#  Rating(user=1000548, product=1009786, rating=8.0),
#  Rating(user=1000548, product=1096144, rating=8.0),
#  Rating(user=1000555, product=1152503, rating=8.0),
#  Rating(user=1000557, product=1034228, rating=8.0),
#  Rating(user=1000557, product=1056505, rating=8.0),
#  Rating(user=1000560, product=1007614, rating=8.0),
#  Rating(user=1000562, product=1000790, rating=8.0),
#  Rating(user=1000562, product=1021323, rating=8.0),
#  Rating(user=1000563, product=1012188, rating=8.0),
#  Rating(user=1000573, product=56, rating=8.0),
#  Rating(user=1000573, product=5820, rating=8.0),
#  Rating(user=1000581, product=1007945, rating=8.0),
#  Rating(user=1000584, product=1274, rating=8.0),
#  Rating(user=1000584, product=2132, rating=8.0),
#  Rating(user=1000589, product=1854, rating=8.0),
#  Rating(user=1000596, product=1009075, rating=8.0),
#  Rating(user=1000598, product=1183, rating=8.0),
#  Rating(user=1000598, product=1289649, rating=8.0),
#  Rating(user=1000604, product=1026191, rating=8.0),
#  Rating(user=1000611, product=1000042, rating=8.0),
#  Rating(user=1000611, product=1005326, rating=8.0),
#  Rating(user=1000611, product=1013892, rating=8.0),
#  Rating(user=1000611, product=1019462, rating=8.0),
#  Rating(user=1000611, product=1326651, rating=8.0),
#  Rating(user=1000611, product=3414, rating=8.0),
#  Rating(user=1000611, product=57, rating=8.0),
#  Rating(user=1000614, product=4471, rating=8.0),
#  Rating(user=1000619, product=411, rating=8.0),
#  Rating(user=1000640, product=1280588, rating=8.0),
#  Rating(user=1000647, product=1100683, rating=8.0),
#  Rating(user=1000647, product=1337445, rating=8.0),
#  Rating(user=1000647, product=6630669, rating=8.0),
#  Rating(user=1000647, product=6631608, rating=8.0),
#  Rating(user=1000651, product=1058862, rating=8.0),
#  Rating(user=1000657, product=733, rating=8.0),
#  Rating(user=1000660, product=1002325, rating=8.0),
#  Rating(user=1000664, product=1000527, rating=8.0),
#  Rating(user=1000664, product=1194065, rating=8.0),
#  Rating(user=1000664, product=2090681, rating=8.0),
#  Rating(user=1000669, product=1255834, rating=8.0),
#  Rating(user=1000687, product=1006260, rating=8.0),
#  Rating(user=1000689, product=153, rating=8.0),
#  Rating(user=1000694, product=1000340, rating=8.0),
#  Rating(user=1000694, product=1008583, rating=8.0),
#  Rating(user=1000701, product=1001068, rating=8.0),
#  Rating(user=1000701, product=1011891, rating=8.0),
#  Rating(user=1000701, product=1175, rating=8.0),
#  Rating(user=1000711, product=1042445, rating=8.0),
#  Rating(user=1000711, product=798, rating=8.0),
#  Rating(user=1000713, product=1234329, rating=8.0),
#  Rating(user=1000717, product=1007614, rating=8.0),
#  Rating(user=1000718, product=4497, rating=8.0),
#  Rating(user=1000719, product=3111, rating=8.0),
#  Rating(user=1000728, product=189, rating=8.0),
#  Rating(user=1000730, product=1304375, rating=8.0),
#  Rating(user=1000736, product=61, rating=8.0),
#  Rating(user=1000742, product=1014707, rating=8.0),
#  Rating(user=1000742, product=1016234, rating=8.0),
#  Rating(user=1000749, product=10416904, rating=8.0),
#  Rating(user=1000750, product=1056567, rating=8.0),
#  Rating(user=1000759, product=1000548, rating=8.0),
#  Rating(user=1000759, product=535, rating=8.0),
#  Rating(user=1000764, product=10631459, rating=8.0),
#  Rating(user=1000764, product=1259, rating=8.0),
#  Rating(user=1000767, product=1002544, rating=8.0),
#  Rating(user=1000767, product=1008846, rating=8.0),
#  Rating(user=1000775, product=1012692, rating=8.0),
#  Rating(user=1000786, product=1001048, rating=8.0),
#  Rating(user=1000786, product=793, rating=8.0),
#  Rating(user=1000787, product=118, rating=8.0),
#  Rating(user=1000793, product=1200, rating=8.0),
#  Rating(user=1000803, product=1004278, rating=8.0),
#  Rating(user=1000809, product=1019281, rating=8.0),
#  Rating(user=1000809, product=5494, rating=8.0),
#  Rating(user=1000815, product=1000435, rating=8.0),
#  Rating(user=1000833, product=1001249, rating=8.0),
#  Rating(user=1000844, product=6789316, rating=8.0),
#  Rating(user=1000846, product=246, rating=8.0),
#  Rating(user=1000846, product=2546, rating=8.0),
#  Rating(user=1000847, product=1300798, rating=8.0),
#  Rating(user=1000847, product=6776453, rating=8.0),
#  Rating(user=1000851, product=1003928, rating=8.0),
#  Rating(user=1000857, product=705, rating=8.0),
#  Rating(user=1000860, product=1004536, rating=8.0),
#  Rating(user=1000860, product=1016821, rating=8.0),
#  Rating(user=1000861, product=1001008, rating=8.0),
#  Rating(user=1000870, product=1005411, rating=8.0),
#  Rating(user=1000870, product=1005616, rating=8.0),
#  Rating(user=1000877, product=1007265, rating=8.0),
#  Rating(user=1000879, product=1190632, rating=8.0),
#  Rating(user=1000879, product=5477, rating=8.0),
#  Rating(user=1000882, product=1011818, rating=8.0),
#  Rating(user=1000892, product=1015823, rating=8.0),
#  Rating(user=1000892, product=1020673, rating=8.0),
#  Rating(user=1000902, product=1003604, rating=8.0),
#  Rating(user=1000909, product=1001534, rating=8.0),
#  Rating(user=1000909, product=1013166, rating=8.0),
#  Rating(user=1000919, product=1000113, rating=8.0),
#  Rating(user=1000919, product=1084937, rating=8.0),
#  Rating(user=1000919, product=1113595, rating=8.0),
#  Rating(user=1000922, product=1010830, rating=8.0),
#  Rating(user=1000924, product=1000952, rating=8.0),
#  Rating(user=1000928, product=1000188, rating=8.0),
#  Rating(user=1000928, product=1001920, rating=8.0),
#  Rating(user=1000928, product=113, rating=8.0),
#  Rating(user=1000932, product=1010528, rating=8.0),
#  Rating(user=1000932, product=1027249, rating=8.0),
#  Rating(user=1000932, product=1247841, rating=8.0),
#  Rating(user=1000933, product=189, rating=8.0),
#  Rating(user=1000933, product=2745, rating=8.0),
#  Rating(user=1000933, product=5925, rating=8.0),
#  Rating(user=1000946, product=1249401, rating=8.0),
#  Rating(user=1000948, product=1026150, rating=8.0),
#  Rating(user=1000948, product=2059184, rating=8.0),
#  Rating(user=1000948, product=4568, rating=8.0),
#  Rating(user=1000951, product=1003585, rating=8.0),
#  Rating(user=1000951, product=742, rating=8.0),
#  Rating(user=1000957, product=1309353, rating=8.0),
#  Rating(user=1000964, product=6834961, rating=8.0),
#  Rating(user=1000965, product=1004207, rating=8.0),
#  Rating(user=1000965, product=339, rating=8.0),
#  Rating(user=1000968, product=1191, rating=8.0),
#  Rating(user=1000968, product=5734, rating=8.0),
#  Rating(user=1000969, product=5452, rating=8.0),
#  Rating(user=1000985, product=45, rating=8.0),
#  Rating(user=1000987, product=1002225, rating=8.0),
#  Rating(user=1000989, product=1000518, rating=8.0),
#  Rating(user=1000991, product=1261668, rating=8.0),
#  Rating(user=1000993, product=1000295, rating=8.0),
#  Rating(user=1000993, product=1000548, rating=8.0),
#  Rating(user=1000993, product=1001347, rating=8.0),
#  Rating(user=1000993, product=1002065, rating=8.0),
#  Rating(user=1000993, product=1071826, rating=8.0),
#  Rating(user=1000993, product=1247540, rating=8.0),
#  Rating(user=1000998, product=979, rating=8.0),
#  Rating(user=1001010, product=69, rating=8.0),
#  Rating(user=1001013, product=1000088, rating=8.0),
#  Rating(user=1001020, product=530, rating=8.0),
#  Rating(user=1001030, product=1247118, rating=8.0),
#  Rating(user=1001030, product=1411, rating=8.0),
#  Rating(user=1001038, product=1205, rating=8.0),
#  Rating(user=1001039, product=1018461, rating=8.0),
#  Rating(user=1001042, product=1007453, rating=8.0),
#  Rating(user=1001052, product=1065921, rating=8.0),
#  Rating(user=1001052, product=1182, rating=8.0),
#  Rating(user=1001052, product=535, rating=8.0),
#  Rating(user=1001053, product=1000570, rating=8.0),
#  Rating(user=1001057, product=1015116, rating=8.0),
#  Rating(user=1001070, product=1001230, rating=8.0),
#  Rating(user=1001070, product=1078626, rating=8.0),
#  Rating(user=1001071, product=1000188, rating=8.0),
#  Rating(user=1001077, product=1040900, rating=8.0),
#  Rating(user=1001077, product=1063178, rating=8.0),
#  Rating(user=1001077, product=5810, rating=8.0),
#  Rating(user=1001080, product=1000442, rating=8.0),
#  Rating(user=1001080, product=1010650, rating=8.0),
#  Rating(user=1001085, product=118, rating=8.0),
#  Rating(user=1001101, product=1015554, rating=8.0),
#  Rating(user=1001102, product=1017871, rating=8.0),
#  Rating(user=1001103, product=4496, rating=8.0),
#  Rating(user=1001106, product=1039843, rating=8.0),
#  Rating(user=1001113, product=1118156, rating=8.0),
#  Rating(user=1001113, product=1199, rating=8.0),
#  Rating(user=1001114, product=1018042, rating=8.0),
#  Rating(user=1001114, product=1034908, rating=8.0),
#  Rating(user=1001114, product=1041272, rating=8.0),
#  Rating(user=1001114, product=1391, rating=8.0),
#  Rating(user=1001114, product=2058, rating=8.0),
#  Rating(user=1001116, product=6833155, rating=8.0),
#  Rating(user=1001118, product=1005509, rating=8.0),
#  Rating(user=1001118, product=2888, rating=8.0),
#  Rating(user=1001129, product=1014136, rating=8.0),
#  Rating(user=1001134, product=1017567, rating=8.0),
#  Rating(user=1001137, product=1006612, rating=8.0),
#  Rating(user=1001137, product=1007815, rating=8.0),
#  Rating(user=1001137, product=5810, rating=8.0),
#  Rating(user=1001142, product=5793, rating=8.0),
#  Rating(user=1001144, product=1010528, rating=8.0),
#  Rating(user=1001145, product=1022669, rating=8.0),
#  Rating(user=1001147, product=1000681, rating=8.0),
#  Rating(user=1001149, product=1006039, rating=8.0),
#  Rating(user=1001153, product=508, rating=8.0),
#  Rating(user=1001155, product=1183, rating=8.0),
#  Rating(user=1001155, product=647, rating=8.0),
#  Rating(user=1001158, product=3083, rating=8.0),
#  Rating(user=1001158, product=4609, rating=8.0),
#  Rating(user=1001161, product=121, rating=8.0),
#  Rating(user=1001167, product=1050311, rating=8.0),
#  Rating(user=1001167, product=2923, rating=8.0),
#  Rating(user=1001174, product=2000027, rating=8.0),
#  Rating(user=1001176, product=1030571, rating=8.0),
#  Rating(user=1001176, product=895, rating=8.0),
#  Rating(user=1001209, product=1001907, rating=8.0),
#  Rating(user=1001212, product=1552, rating=8.0),
#  Rating(user=1001213, product=1000241, rating=8.0),
#  Rating(user=1001215, product=1003727, rating=8.0),
#  Rating(user=1001217, product=1008343, rating=8.0),
#  Rating(user=1001217, product=1040892, rating=8.0),
#  Rating(user=1001220, product=1004142, rating=8.0),
#  Rating(user=1001229, product=1021180, rating=8.0),
#  Rating(user=1001250, product=1020621, rating=8.0),
#  Rating(user=1001253, product=1014901, rating=8.0),
#  Rating(user=1001264, product=1004416, rating=8.0),
#  Rating(user=1001274, product=478, rating=8.0),
#  Rating(user=1001286, product=1092053, rating=8.0),
#  Rating(user=1001288, product=1148861, rating=8.0),
#  Rating(user=1001296, product=1200, rating=8.0),
#  Rating(user=1001298, product=1000985, rating=8.0),
#  Rating(user=1001301, product=1119921, rating=8.0),
#  Rating(user=1001301, product=1250104, rating=8.0),
#  Rating(user=1001301, product=202, rating=8.0),
#  Rating(user=1001303, product=1515, rating=8.0),
#  Rating(user=1001303, product=508, rating=8.0),
#  Rating(user=1001310, product=1053860, rating=8.0),
#  Rating(user=1001310, product=3604, rating=8.0),
#  Rating(user=1001314, product=1014937, rating=8.0),
#  Rating(user=1001322, product=3170, rating=8.0),
#  Rating(user=1001322, product=4465, rating=8.0),
#  Rating(user=1001322, product=78, rating=8.0),
#  Rating(user=1001333, product=1005175, rating=8.0),
#  Rating(user=1001343, product=1000136, rating=8.0),
#  Rating(user=1001343, product=1000699, rating=8.0),
#  Rating(user=1001343, product=1001052, rating=8.0),
#  Rating(user=1001343, product=1010650, rating=8.0),
#  Rating(user=1001343, product=1012042, rating=8.0),
#  Rating(user=1001346, product=1000836, rating=8.0),
#  Rating(user=1001346, product=1002310, rating=8.0),
#  Rating(user=1001347, product=1011470, rating=8.0),
#  Rating(user=1001347, product=1036842, rating=8.0),
#  Rating(user=1001349, product=1001597, rating=8.0),
#  Rating(user=1001349, product=1017443, rating=8.0),
#  Rating(user=1001357, product=1030401, rating=8.0),
#  Rating(user=1001357, product=1059696, rating=8.0),
#  Rating(user=1001357, product=2098747, rating=8.0),
#  Rating(user=1001357, product=3402, rating=8.0),
#  Rating(user=1001358, product=1022427, rating=8.0),
#  Rating(user=1001358, product=1133458, rating=8.0),
#  Rating(user=1001360, product=1000952, rating=8.0),
#  Rating(user=1001361, product=1001328, rating=8.0),
#  Rating(user=1001362, product=1021134, rating=8.0),
#  Rating(user=1001365, product=1031609, rating=8.0),
#  Rating(user=1001365, product=1036024, rating=8.0),
#  Rating(user=1001371, product=3033, rating=8.0),
#  Rating(user=1001372, product=1004732, rating=8.0),
#  Rating(user=1001375, product=1011299, rating=8.0),
#  Rating(user=1001381, product=1023054, rating=8.0),
#  Rating(user=1001381, product=364, rating=8.0),
#  Rating(user=1001389, product=1001534, rating=8.0),
#  Rating(user=1001398, product=1001907, rating=8.0),
#  Rating(user=1001399, product=1060324, rating=8.0),
#  Rating(user=1001402, product=2045507, rating=8.0),
#  Rating(user=1001404, product=1022186, rating=8.0),
#  Rating(user=1001408, product=1011262, rating=8.0),
#  Rating(user=1001408, product=202, rating=8.0),
#  Rating(user=1001419, product=1177, rating=8.0),
#  Rating(user=1001421, product=4922, rating=8.0),
#  Rating(user=1001421, product=553, rating=8.0),
#  Rating(user=1001429, product=1004109, rating=8.0),
#  Rating(user=1001429, product=1056496, rating=8.0),
#  Rating(user=1001438, product=63, rating=8.0),
#  Rating(user=1001439, product=1235281, rating=8.0),
#  Rating(user=1001440, product=1004450, rating=8.0),
#  Rating(user=1001440, product=1030806, rating=8.0),
#  Rating(user=1001440, product=1038175, rating=8.0),
#  Rating(user=1001440, product=1235682, rating=8.0),
#  Rating(user=1001440, product=1244340, rating=8.0),
#  Rating(user=1001440, product=1244726, rating=8.0),
#  Rating(user=1001440, product=6873296, rating=8.0),
#  Rating(user=1001448, product=1000435, rating=8.0),
#  Rating(user=1001448, product=1009593, rating=8.0),
#  Rating(user=1001454, product=153, rating=8.0),
#  Rating(user=1001456, product=1018735, rating=8.0),
#  Rating(user=1001462, product=1004296, rating=8.0),
#  Rating(user=1001469, product=1193, rating=8.0),
#  Rating(user=1001469, product=1233381, rating=8.0),
#  Rating(user=1001476, product=1003771, rating=8.0),
#  Rating(user=1001476, product=1027914, rating=8.0),
#  Rating(user=1001476, product=6918910, rating=8.0),
#  Rating(user=1001478, product=234, rating=8.0),
#  Rating(user=1001478, product=776, rating=8.0),
#  Rating(user=1001479, product=1001607, rating=8.0),
#  Rating(user=1001481, product=1078729, rating=8.0),
#  Rating(user=1001483, product=1004415, rating=8.0),
#  Rating(user=1001483, product=1259423, rating=8.0),
#  Rating(user=1001487, product=1004118, rating=8.0),
#  Rating(user=1001487, product=1043844, rating=8.0),
#  Rating(user=1001490, product=2017, rating=8.0),
#  Rating(user=1001491, product=1014807, rating=8.0),
#  Rating(user=1001491, product=1236879, rating=8.0),
#  Rating(user=1001504, product=1312450, rating=8.0),
#  Rating(user=1001512, product=4567, rating=8.0),
#  Rating(user=1001512, product=5705, rating=8.0),
#  Rating(user=1001515, product=28, rating=8.0),
#  Rating(user=1001515, product=490, rating=8.0),
#  Rating(user=1001516, product=1008335, rating=8.0),
#  Rating(user=1001516, product=4471, rating=8.0),
#  Rating(user=1001523, product=1004518, rating=8.0),
#  Rating(user=1001529, product=1047403, rating=8.0),
#  Rating(user=1001535, product=1003358, rating=8.0),
#  Rating(user=1001540, product=1000210, rating=8.0),
#  Rating(user=1001542, product=463, rating=8.0),
#  Rating(user=1001547, product=1006834, rating=8.0),
#  Rating(user=1001547, product=1262245, rating=8.0),
#  Rating(user=1001547, product=1038212, rating=8.0),
#  Rating(user=1001549, product=830, rating=8.0),
#  Rating(user=1001552, product=1013939, rating=8.0),
#  Rating(user=1001562, product=1125803, rating=8.0),
#  Rating(user=1001562, product=2823, rating=8.0),
#  Rating(user=1001587, product=1003850, rating=8.0),
#  Rating(user=1001596, product=979, rating=8.0),
#  Rating(user=1001604, product=1001534, rating=8.0),
#  Rating(user=1001604, product=1268809, rating=8.0),
#  Rating(user=1001606, product=1001365, rating=8.0),
#  Rating(user=1001606, product=1039016, rating=8.0),
#  Rating(user=1001606, product=1175072, rating=8.0),
#  Rating(user=1001606, product=1233960, rating=8.0),
#  Rating(user=1001606, product=4241, rating=8.0),
#  Rating(user=1001606, product=9943382, rating=8.0),
#  Rating(user=1001615, product=357, rating=8.0),
#  Rating(user=1001618, product=1007498, rating=8.0),
#  Rating(user=1001626, product=1010921, rating=8.0),
#  Rating(user=1001626, product=699, rating=8.0),
#  Rating(user=1001647, product=1273864, rating=8.0),
#  Rating(user=1001662, product=1001307, rating=8.0),
#  Rating(user=1001663, product=1000157, rating=8.0),
#  Rating(user=1001673, product=1016582, rating=8.0),
#  Rating(user=1001673, product=1230, rating=8.0),
#  Rating(user=1001674, product=1027713, rating=8.0),
#  Rating(user=1001674, product=1296798, rating=8.0),
#  Rating(user=1001677, product=1239283, rating=8.0),
#  Rating(user=1001679, product=1020, rating=8.0),
#  Rating(user=1001687, product=2231, rating=8.0),
#  Rating(user=1001699, product=1005846, rating=8.0),
#  Rating(user=1001699, product=1033782, rating=8.0),
#  Rating(user=1001699, product=1074566, rating=8.0),
#  Rating(user=1001699, product=1258353, rating=8.0),
#  Rating(user=1001699, product=313, rating=8.0),
#  Rating(user=1001706, product=1028961, rating=8.0),
#  Rating(user=1001712, product=1030954, rating=8.0),
#  Rating(user=1001718, product=1334770, rating=8.0),
#  Rating(user=1001720, product=1031648, rating=8.0),
#  Rating(user=1001728, product=1001864, rating=8.0),
#  Rating(user=1001731, product=1001141, rating=8.0),
#  Rating(user=1001731, product=1688, rating=8.0),
#  Rating(user=1001741, product=4100, rating=8.0),
#  Rating(user=1001746, product=1004758, rating=8.0),
#  Rating(user=1001746, product=1007307, rating=8.0),
#  Rating(user=1001746, product=1017592, rating=8.0),
#  Rating(user=1001746, product=1331146, rating=8.0),
#  Rating(user=1001747, product=1017268, rating=8.0),
#  Rating(user=1001747, product=299, rating=8.0),
#  Rating(user=1001753, product=1002075, rating=8.0),
#  Rating(user=1001754, product=1811, rating=8.0),
#  Rating(user=1001758, product=1013208, rating=8.0),
#  Rating(user=1001759, product=111, rating=8.0),
#  Rating(user=1001773, product=4622, rating=8.0),
#  Rating(user=1001777, product=1005226, rating=8.0),
#  Rating(user=1001777, product=604, rating=8.0),
#  Rating(user=1001779, product=1319, rating=8.0),
#  Rating(user=1001779, product=232, rating=8.0),
#  Rating(user=1001782, product=1237884, rating=8.0),
#  Rating(user=1001782, product=2075705, rating=8.0),
#  Rating(user=1001782, product=615, rating=8.0),
#  Rating(user=1001783, product=939, rating=8.0),
#  Rating(user=1001789, product=1086, rating=8.0),
#  Rating(user=1001789, product=601, rating=8.0),
#  Rating(user=1001800, product=1257123, rating=8.0),
#  Rating(user=1001801, product=1051672, rating=8.0),
#  Rating(user=1001804, product=251, rating=8.0),
#  Rating(user=1001814, product=1651, rating=8.0),
#  Rating(user=1001819, product=860, rating=8.0),
#  Rating(user=1001820, product=2799, rating=8.0),
#  Rating(user=1001824, product=1009511, rating=8.0),
#  Rating(user=1001826, product=1000329, rating=8.0),
#  Rating(user=1001826, product=1001646, rating=8.0),
#  Rating(user=1001830, product=1002584, rating=8.0),
#  Rating(user=1001830, product=1061651, rating=8.0),
#  Rating(user=1001830, product=1193, rating=8.0),
#  Rating(user=1001831, product=1000113, rating=8.0),
#  Rating(user=1001841, product=1015392, rating=8.0),
#  Rating(user=1001843, product=1000982, rating=8.0),
#  Rating(user=1001843, product=1001582, rating=8.0),
#  Rating(user=1001843, product=10589268, rating=8.0),
#  Rating(user=1001843, product=1061270, rating=8.0),
#  Rating(user=1001849, product=313, rating=8.0),
#  Rating(user=1001852, product=1194, rating=8.0),
#  Rating(user=1001855, product=1069734, rating=8.0),
#  Rating(user=1001856, product=1006026, rating=8.0),
#  Rating(user=1001856, product=2569, rating=8.0),
#  Rating(user=1001861, product=1001858, rating=8.0),
#  Rating(user=1001866, product=4468, rating=8.0),
#  Rating(user=1001872, product=2026395, rating=8.0),
#  Rating(user=1001872, product=6966095, rating=8.0),
#  Rating(user=1001875, product=1048868, rating=8.0),
#  Rating(user=1001876, product=4499, rating=8.0),
#  Rating(user=1001879, product=1195, rating=8.0),
#  Rating(user=1001879, product=1651, rating=8.0),
#  Rating(user=1001886, product=1034635, rating=8.0),
#  Rating(user=1001886, product=600, rating=8.0),
#  Rating(user=1001892, product=1890, rating=8.0),
#  Rating(user=1001894, product=1207624, rating=8.0),
#  Rating(user=1001894, product=1233696, rating=8.0),
#  Rating(user=1001894, product=6618589, rating=8.0),
#  Rating(user=1001894, product=6975448, rating=8.0),
#  Rating(user=1001895, product=1248046, rating=8.0),
#  Rating(user=1001895, product=759, rating=8.0),
#  Rating(user=1001896, product=1001989, rating=8.0),
#  Rating(user=1001896, product=1003167, rating=8.0),
#  Rating(user=1001896, product=1003809, rating=8.0),
#  Rating(user=1001896, product=1004349, rating=8.0),
#  Rating(user=1001896, product=1039639, rating=8.0),
#  Rating(user=1001905, product=5197, rating=8.0),
#  Rating(user=1001911, product=2850, rating=8.0),
#  Rating(user=1001914, product=976, rating=8.0),
#  Rating(user=1001917, product=1002556, rating=8.0),
#  Rating(user=1001919, product=1000698, rating=8.0),
#  Rating(user=1001919, product=1002604, rating=8.0),
#  Rating(user=1001919, product=1031861, rating=8.0),
#  Rating(user=1001919, product=1049293, rating=8.0),
#  Rating(user=1001922, product=2484, rating=8.0),
#  Rating(user=1001932, product=1018807, rating=8.0),
#  Rating(user=1001932, product=1016018, rating=8.0),
#  Rating(user=1001939, product=1238269, rating=8.0),
#  Rating(user=1001946, product=1001646, rating=8.0),
#  Rating(user=1001948, product=2054010, rating=8.0),
#  Rating(user=1001950, product=807, rating=8.0),
#  Rating(user=1001955, product=1075309, rating=8.0),
#  Rating(user=1001956, product=1000591, rating=8.0),
#  Rating(user=1001956, product=1065827, rating=8.0),
#  Rating(user=1001956, product=1466, rating=8.0),
#  Rating(user=1001964, product=1394, rating=8.0),
#  Rating(user=1001964, product=3150, rating=8.0),
#  Rating(user=1001968, product=1000266, rating=8.0),
#  Rating(user=1001968, product=1018934, rating=8.0),
#  Rating(user=1001978, product=1000056, rating=8.0),
#  Rating(user=1001978, product=2231, rating=8.0),
#  Rating(user=1001979, product=1004077, rating=8.0),
#  Rating(user=1001990, product=676, rating=8.0),
#  Rating(user=1002001, product=2238, rating=8.0),
#  Rating(user=1002005, product=1006332, rating=8.0),
#  Rating(user=1002031, product=1270639, rating=8.0),
#  Rating(user=1002031, product=1414, rating=8.0),
#  Rating(user=1002037, product=1001735, rating=8.0),
#  Rating(user=1002038, product=83, rating=8.0),
#  Rating(user=1002039, product=4465, rating=8.0),
#  Rating(user=1002046, product=1001392, rating=8.0),
#  Rating(user=1002046, product=1026628, rating=8.0),
#  Rating(user=1002046, product=1091409, rating=8.0),
#  Rating(user=1002046, product=1189599, rating=8.0),
#  Rating(user=1002046, product=2030119, rating=8.0),
#  Rating(user=1002062, product=1252, rating=8.0),
#  Rating(user=1002068, product=1037598, rating=8.0),
#  Rating(user=1002076, product=1006334, rating=8.0),
#  Rating(user=1002080, product=1266817, rating=8.0),
#  Rating(user=1002080, product=1038811, rating=8.0),
#  Rating(user=1002083, product=1001424, rating=8.0),
#  Rating(user=1002101, product=1179, rating=8.0),
#  Rating(user=1002102, product=4241, rating=8.0),
#  Rating(user=1002105, product=1145952, rating=8.0),
#  Rating(user=1002105, product=1384, rating=8.0),
#  Rating(user=1002115, product=1001646, rating=8.0),
#  Rating(user=1002122, product=2232, rating=8.0),
#  Rating(user=1002123, product=2161373, rating=8.0),
#  Rating(user=1002125, product=1411, rating=8.0),
#  Rating(user=1002125, product=18, rating=8.0),
#  Rating(user=1002131, product=1000518, rating=8.0),
#  Rating(user=1002132, product=1000445, rating=8.0),
#  Rating(user=1002135, product=4267, rating=8.0),
#  Rating(user=1002141, product=1007856, rating=8.0),
#  Rating(user=1002145, product=1000045, rating=8.0),
#  Rating(user=1002155, product=1267999, rating=8.0),
#  Rating(user=1002157, product=1002456, rating=8.0),
#  Rating(user=1002165, product=1021356, rating=8.0),
#  Rating(user=1002165, product=1066625, rating=8.0),
#  Rating(user=1002165, product=1410, rating=8.0),
#  Rating(user=1002172, product=1001368, rating=8.0),
#  Rating(user=1002172, product=1003681, rating=8.0),
#  Rating(user=1002172, product=1007735, rating=8.0),
#  Rating(user=1002172, product=1305, rating=8.0),
#  Rating(user=1002185, product=1010695, rating=8.0),
#  Rating(user=1002185, product=1048381, rating=8.0),
#  Rating(user=1002185, product=1072819, rating=8.0),
#  Rating(user=1002185, product=1078493, rating=8.0),
#  Rating(user=1002185, product=1206905, rating=8.0),
#  Rating(user=1002185, product=1338871, rating=8.0),
#  Rating(user=1002193, product=4316, rating=8.0),
#  Rating(user=1002195, product=1002404, rating=8.0),
#  Rating(user=1002196, product=1000010, rating=8.0),
#  Rating(user=1002213, product=1019171, rating=8.0),
#  Rating(user=1002213, product=1044981, rating=8.0),
#  Rating(user=1002220, product=969, rating=8.0),
#  Rating(user=1002222, product=1000060, rating=8.0),
#  Rating(user=1002222, product=1233107, rating=8.0),
#  Rating(user=1002222, product=6605893, rating=8.0),
#  Rating(user=1002231, product=4483, rating=8.0),
#  Rating(user=1002231, product=5410, rating=8.0),
#  Rating(user=1002235, product=1043847, rating=8.0),
#  Rating(user=1002235, product=285, rating=8.0),
#  Rating(user=1002237, product=1019931, rating=8.0),
#  Rating(user=1002237, product=1234259, rating=8.0),
#  Rating(user=1002241, product=1010227, rating=8.0),
#  Rating(user=1002242, product=1003780, rating=8.0),
#  Rating(user=1002245, product=1018807, rating=8.0),
#  Rating(user=1002245, product=251, rating=8.0),
#  Rating(user=1002250, product=1052430, rating=8.0),
#  Rating(user=1002252, product=1008936, rating=8.0),
#  Rating(user=1002254, product=1001657, rating=8.0),
#  Rating(user=1002254, product=1192602, rating=8.0),
#  Rating(user=1002254, product=4481, rating=8.0),
#  Rating(user=1002271, product=1001419, rating=8.0),
#  Rating(user=1002271, product=1786, rating=8.0),
#  Rating(user=1002271, product=5837, rating=8.0),
#  Rating(user=1002272, product=1000624, rating=8.0),
#  Rating(user=1002276, product=1014069, rating=8.0),
#  Rating(user=1002276, product=2617, rating=8.0),
#  Rating(user=1002284, product=1002908, rating=8.0),
#  Rating(user=1002284, product=1247913, rating=8.0),
#  Rating(user=1002284, product=82, rating=8.0),
#  Rating(user=1002286, product=1233193, rating=8.0),
#  Rating(user=1002287, product=893, rating=8.0),
#  Rating(user=1002296, product=1020975, rating=8.0),
#  Rating(user=1002300, product=1016670, rating=8.0),
#  Rating(user=1002308, product=2132, rating=8.0),
#  Rating(user=1002310, product=1014421, rating=8.0),
#  Rating(user=1002310, product=1784, rating=8.0),
#  Rating(user=1002312, product=1074374, rating=8.0),
#  Rating(user=1002315, product=1256375, rating=8.0),
#  Rating(user=1002316, product=3325, rating=8.0),
#  Rating(user=1002319, product=1252210, rating=8.0),
#  Rating(user=1002331, product=1327, rating=8.0),
#  Rating(user=1002341, product=979, rating=8.0),
#  Rating(user=1002342, product=1001891, rating=8.0),
#  Rating(user=1002345, product=62, rating=8.0),
#  Rating(user=1002346, product=1014463, rating=8.0),
#  Rating(user=1002356, product=1014860, rating=8.0),
#  Rating(user=1002362, product=1006924, rating=8.0),
#  Rating(user=1002362, product=358, rating=8.0),
#  Rating(user=1002375, product=1253284, rating=8.0),
#  Rating(user=1002389, product=1003557, rating=8.0),
#  Rating(user=1002389, product=1006320, rating=8.0),
#  Rating(user=1002389, product=1033351, rating=8.0),
#  Rating(user=1002396, product=1234431, rating=8.0),
#  Rating(user=1002403, product=5626, rating=8.0),
#  Rating(user=1002408, product=1002225, rating=8.0),
#  Rating(user=1002408, product=1047813, rating=8.0),
#  Rating(user=1002412, product=1196, rating=8.0),
#  Rating(user=1002414, product=1001365, rating=8.0),
#  Rating(user=1002417, product=1306, rating=8.0),
#  Rating(user=1002420, product=1019636, rating=8.0),
#  Rating(user=1002420, product=1019649, rating=8.0),
#  Rating(user=1002420, product=1282969, rating=8.0),
#  Rating(user=1002422, product=1000175, rating=8.0),
#  Rating(user=1002422, product=1057272, rating=8.0),
#  Rating(user=1002423, product=1236021, rating=8.0),
#  Rating(user=1002423, product=5203, rating=8.0),
#  Rating(user=1002426, product=1006094, rating=8.0),
#  Rating(user=1002426, product=1263859, rating=8.0),
#  Rating(user=1002428, product=1009898, rating=8.0),
#  Rating(user=1002428, product=1029867, rating=8.0),
#  Rating(user=1002428, product=5055, rating=8.0),
#  Rating(user=1002431, product=733, rating=8.0),
#  Rating(user=1002434, product=930, rating=8.0),
#  Rating(user=1002440, product=1014651, rating=8.0),
#  Rating(user=1002454, product=1000991, rating=8.0),
#  Rating(user=1002454, product=1004241, rating=8.0),
#  Rating(user=1002454, product=1257269, rating=8.0),
#  Rating(user=1002454, product=2819, rating=8.0),
#  Rating(user=1002460, product=2013196, rating=8.0),
#  Rating(user=1002464, product=3327, rating=8.0),
#  Rating(user=1002465, product=1003147, rating=8.0),
#  Rating(user=1002488, product=1002770, rating=8.0),
#  Rating(user=1002489, product=1045695, rating=8.0),
#  Rating(user=1002491, product=1000473, rating=8.0),
#  Rating(user=1002494, product=1000724, rating=8.0),
#  Rating(user=1002498, product=831, rating=8.0),
#  Rating(user=1002499, product=1015261, rating=8.0),
#  Rating(user=1002501, product=1013380, rating=8.0),
#  Rating(user=1002503, product=3327, rating=8.0),
#  Rating(user=1002507, product=1245208, rating=8.0),
#  Rating(user=1002507, product=2, rating=8.0),
#  Rating(user=1002511, product=1000445, rating=8.0),
#  Rating(user=1002511, product=1001483, rating=8.0),
#  Rating(user=1002511, product=1105368, rating=8.0),
#  Rating(user=1002511, product=1200198, rating=8.0),
#  Rating(user=1002511, product=1257182, rating=8.0),
#  Rating(user=1002520, product=1004174, rating=8.0),
#  Rating(user=1002523, product=1035881, rating=8.0),
#  Rating(user=1002525, product=1003809, rating=8.0),
#  Rating(user=1002525, product=1003014, rating=8.0),
#  Rating(user=1002528, product=1013938, rating=8.0),
#  Rating(user=1002531, product=1006053, rating=8.0),
#  Rating(user=1002531, product=71, rating=8.0),
#  Rating(user=1002535, product=1014531, rating=8.0),
#  Rating(user=1002550, product=1002579, rating=8.0),
#  Rating(user=1002551, product=1844, rating=8.0),
#  Rating(user=1002561, product=1000738, rating=8.0),
#  Rating(user=1002561, product=4061, rating=8.0),
#  Rating(user=1002563, product=1000591, rating=8.0),
#  Rating(user=1002567, product=1259, rating=8.0),
#  Rating(user=1002567, product=4605, rating=8.0),
#  Rating(user=1002577, product=1000982, rating=8.0),
#  Rating(user=1002579, product=1403, rating=8.0),
#  Rating(user=1002590, product=1000557, rating=8.0),
#  Rating(user=1002592, product=1289, rating=8.0),
#  Rating(user=1002612, product=1003282, rating=8.0),
#  Rating(user=1002612, product=1069007, rating=8.0),
#  Rating(user=1002612, product=1201, rating=8.0),
#  Rating(user=1002612, product=1236306, rating=8.0),
#  Rating(user=1002612, product=1280586, rating=8.0),
#  Rating(user=1002612, product=4505, rating=8.0),
#  Rating(user=1002624, product=1077183, rating=8.0),
#  Rating(user=1002624, product=1451, rating=8.0),
#  Rating(user=1002626, product=4711, rating=8.0),
#  Rating(user=1002641, product=1000201, rating=8.0),
#  Rating(user=1002646, product=1008497, rating=8.0),
#  Rating(user=1002646, product=1234200, rating=8.0),
#  Rating(user=1002646, product=28, rating=8.0),
#  Rating(user=1002648, product=1003083, rating=8.0),
#  Rating(user=1002648, product=1007968, rating=8.0),
#  Rating(user=1002648, product=2121256, rating=8.0),
#  Rating(user=1002648, product=360, rating=8.0),
#  Rating(user=1002648, product=5640, rating=8.0),
#  Rating(user=1002655, product=3444, rating=8.0),
#  Rating(user=1002657, product=3326, rating=8.0),
#  Rating(user=1002658, product=1060636, rating=8.0),
#  Rating(user=1002664, product=1000591, rating=8.0),
#  Rating(user=1002664, product=1007903, rating=8.0),
#  Rating(user=1002664, product=1843, rating=8.0),
#  Rating(user=1002667, product=4246, rating=8.0),
#  Rating(user=1002671, product=1223, rating=8.0),
#  Rating(user=1002675, product=1005234, rating=8.0),
#  Rating(user=1002686, product=1008818, rating=8.0),
#  Rating(user=1002688, product=1008323, rating=8.0),
#  Rating(user=1002688, product=4154, rating=8.0),
#  Rating(user=1002693, product=1011524, rating=8.0),
#  Rating(user=1002695, product=300, rating=8.0),
#  Rating(user=1002702, product=1019931, rating=8.0),
#  Rating(user=1002702, product=1028155, rating=8.0),
#  Rating(user=1002702, product=666, rating=8.0),
#  Rating(user=1002705, product=1280287, rating=8.0),
#  Rating(user=1002728, product=2132, rating=8.0),
#  Rating(user=1002728, product=5606, rating=8.0),
#  Rating(user=1002736, product=1000952, rating=8.0),
#  Rating(user=1002738, product=1003780, rating=8.0),
#  Rating(user=1002742, product=1240103, rating=8.0),
#  Rating(user=1002778, product=1890, rating=8.0),
#  Rating(user=1002779, product=2164, rating=8.0),
#  Rating(user=1002781, product=1004347, rating=8.0),
#  Rating(user=1002781, product=1006169, rating=8.0),
#  Rating(user=1002781, product=1026470, rating=8.0),
#  Rating(user=1002781, product=1986, rating=8.0),
#  Rating(user=1002783, product=1244142, rating=8.0),
#  Rating(user=1002787, product=344, rating=8.0),
#  Rating(user=1002791, product=1844, rating=8.0),
#  Rating(user=1002794, product=1050781, rating=8.0),
#  Rating(user=1002798, product=3326, rating=8.0),
#  Rating(user=1002801, product=238, rating=8.0),
#  Rating(user=1002808, product=1002065, rating=8.0),
#  Rating(user=1002808, product=1045015, rating=8.0),
#  Rating(user=1002823, product=1231740, rating=8.0),
#  Rating(user=1002824, product=1002661, rating=8.0),
#  Rating(user=1002824, product=1003540, rating=8.0),
#  Rating(user=1002828, product=1007611, rating=8.0),
#  Rating(user=1002833, product=1000737, rating=8.0),
#  Rating(user=1002833, product=2819, rating=8.0),
#  Rating(user=1002841, product=1007094, rating=8.0),
#  Rating(user=1002844, product=1051152, rating=8.0),
#  Rating(user=1002846, product=1007500, rating=8.0),
#  Rating(user=1002850, product=1110, rating=8.0),
#  Rating(user=1002851, product=1010249, rating=8.0),
#  Rating(user=1002852, product=1002066, rating=8.0),
#  Rating(user=1002852, product=1025802, rating=8.0),
#  Rating(user=1002858, product=1080445, rating=8.0),
#  Rating(user=1002861, product=441, rating=8.0),
#  Rating(user=1002888, product=1049330, rating=8.0),
#  Rating(user=1002888, product=1089194, rating=8.0),
#  Rating(user=1002892, product=1046426, rating=8.0),
#  Rating(user=1002893, product=1066533, rating=8.0),
#  Rating(user=1002895, product=1039759, rating=8.0),
#  Rating(user=1002906, product=1003346, rating=8.0),
#  Rating(user=1002912, product=1240103, rating=8.0),
#  Rating(user=1002918, product=1001229, rating=8.0),
#  Rating(user=1002918, product=1005820, rating=8.0),
#  Rating(user=1002923, product=1000768, rating=8.0),
#  Rating(user=1002923, product=1260964, rating=8.0),
#  Rating(user=1002924, product=1000107, rating=8.0),
#  Rating(user=1002926, product=1234182, rating=8.0),
#  Rating(user=1002941, product=1003284, rating=8.0),
#  Rating(user=1002947, product=602, rating=8.0),
#  Rating(user=1002949, product=1000199, rating=8.0),
#  Rating(user=1002949, product=1285825, rating=8.0),
#  Rating(user=1002951, product=1062353, rating=8.0),
#  Rating(user=1002951, product=438, rating=8.0),
#  Rating(user=1002960, product=4567, rating=8.0),
#  Rating(user=1002974, product=4621, rating=8.0),
#  Rating(user=1002984, product=3320, rating=8.0),
#  Rating(user=1002986, product=1000384, rating=8.0),
#  Rating(user=1002987, product=1019945, rating=8.0),
#  Rating(user=1002999, product=1001412, rating=8.0),
#  Rating(user=1002999, product=1016328, rating=8.0),
#  Rating(user=1002999, product=1071690, rating=8.0),
#  Rating(user=1002999, product=979, rating=8.0),
#  Rating(user=1003000, product=1001523, rating=8.0),
#  Rating(user=1003000, product=1238467, rating=8.0),
#  Rating(user=1003005, product=1037547, rating=8.0),
#  Rating(user=1003005, product=1059915, rating=8.0),
#  Rating(user=1003008, product=1016279, rating=8.0),
#  Rating(user=1003008, product=1305325, rating=8.0),
#  Rating(user=1003011, product=4061, rating=8.0),
#  Rating(user=1003017, product=1019163, rating=8.0),
#  Rating(user=1003017, product=1035289, rating=8.0),
#  Rating(user=1003017, product=1048160, rating=8.0),
#  Rating(user=1003017, product=1233222, rating=8.0),
#  Rating(user=1003020, product=1002404, rating=8.0),
#  Rating(user=1003020, product=275, rating=8.0),
#  Rating(user=1003022, product=1255913, rating=8.0),
#  Rating(user=1003022, product=1297056, rating=8.0),
#  Rating(user=1003022, product=2569, rating=8.0),
#  Rating(user=1003025, product=742, rating=8.0),
#  Rating(user=1003029, product=1118944, rating=8.0),
#  Rating(user=1003038, product=1030685, rating=8.0),
#  Rating(user=1003038, product=2038100, rating=8.0),
#  Rating(user=1003038, product=3791, rating=8.0),
#  Rating(user=1003042, product=82, rating=8.0),
#  Rating(user=1003045, product=1022618, rating=8.0),
#  Rating(user=1003045, product=1262123, rating=8.0),
#  Rating(user=1003045, product=2139, rating=8.0),
#  Rating(user=1003045, product=6637679, rating=8.0),
#  Rating(user=1003048, product=1000737, rating=8.0),
#  Rating(user=1003048, product=1006896, rating=8.0),
#  Rating(user=1003048, product=1181388, rating=8.0),
#  Rating(user=1003048, product=1235281, rating=8.0),
#  Rating(user=1003061, product=1000557, rating=8.0),
#  Rating(user=1003061, product=1238013, rating=8.0),
#  Rating(user=1003063, product=1000569, rating=8.0),
#  Rating(user=1003067, product=2083, rating=8.0),
#  Rating(user=1003070, product=1001169, rating=8.0),
#  Rating(user=1003077, product=1022392, rating=8.0),
#  Rating(user=1003082, product=1002862, rating=8.0),
#  Rating(user=1003082, product=1015489, rating=8.0),
#  Rating(user=1003090, product=1000188, rating=8.0),
#  Rating(user=1003095, product=1002065, rating=8.0),
#  Rating(user=1003099, product=844, rating=8.0),
#  Rating(user=1003124, product=2017, rating=8.0),
#  Rating(user=1003124, product=6895298, rating=8.0),
#  Rating(user=1003130, product=1008663, rating=8.0),
#  Rating(user=1003140, product=930, rating=8.0),
#  Rating(user=1003207, product=1000388, rating=8.0),
#  Rating(user=1003225, product=1000938, rating=8.0),
#  Rating(user=1003248, product=1005081, rating=8.0),
#  Rating(user=1003266, product=1024948, rating=8.0),
#  Rating(user=1003276, product=1015448, rating=8.0),
#  Rating(user=1003278, product=1006894, rating=8.0),
#  Rating(user=1003281, product=1040883, rating=8.0),
#  Rating(user=1003281, product=1316263, rating=8.0),
#  Rating(user=1003281, product=503, rating=8.0),
#  Rating(user=1003300, product=1008092, rating=8.0),
#  Rating(user=1003300, product=675, rating=8.0),
#  Rating(user=1003303, product=1055445, rating=8.0),
#  Rating(user=1003303, product=1064476, rating=8.0),
#  Rating(user=1003303, product=1240979, rating=8.0),
#  Rating(user=1003303, product=793, rating=8.0),
#  Rating(user=1003307, product=1236255, rating=8.0),
#  Rating(user=1003317, product=1003139, rating=8.0),
#  Rating(user=1003317, product=1236850, rating=8.0),
#  Rating(user=1003317, product=742, rating=8.0),
#  Rating(user=1003319, product=2185, rating=8.0),
#  Rating(user=1003327, product=1035334, rating=8.0),
#  Rating(user=1003348, product=3327, rating=8.0),
#  Rating(user=1003348, product=691, rating=8.0),
#  Rating(user=1003374, product=6755849, rating=8.0),
#  Rating(user=1003407, product=1026675, rating=8.0),
#  Rating(user=1003407, product=82, rating=8.0),
#  Rating(user=1003441, product=1007187, rating=8.0),
#  Rating(user=1003451, product=1003199, rating=8.0),
#  Rating(user=1003451, product=1013944, rating=8.0),
#  Rating(user=1003451, product=1026835, rating=8.0),
#  Rating(user=1003451, product=1056891, rating=8.0),
#  Rating(user=1003451, product=4568, rating=8.0),
#  Rating(user=1003451, product=5180, rating=8.0),
#  Rating(user=1003451, product=63, rating=8.0),
#  Rating(user=1003464, product=2779, rating=8.0),
#  Rating(user=1003468, product=1005937, rating=8.0),
#  Rating(user=1003489, product=2165841, rating=8.0),
#  Rating(user=1003509, product=1013187, rating=8.0),
#  Rating(user=1003529, product=137, rating=8.0),
#  Rating(user=1003530, product=1005039, rating=8.0),
#  Rating(user=1003530, product=438, rating=8.0),
#  Rating(user=1003534, product=785, rating=8.0),
#  Rating(user=1003562, product=1129243, rating=8.0),
#  Rating(user=1003562, product=1303, rating=8.0),
#  Rating(user=1003586, product=1016112, rating=8.0),
#  Rating(user=1003586, product=435, rating=8.0),
#  Rating(user=1003589, product=1009936, rating=8.0),
#  Rating(user=1003589, product=1037970, rating=8.0),
#  Rating(user=1003589, product=1331277, rating=8.0),
#  Rating(user=1003589, product=297, rating=8.0),
#  Rating(user=1003591, product=1010682, rating=8.0),
#  Rating(user=1003591, product=1012457, rating=8.0),
#  Rating(user=1003605, product=2072112, rating=8.0),
#  Rating(user=1003605, product=2125531, rating=8.0),
#  Rating(user=1003609, product=377, rating=8.0),
#  Rating(user=1003628, product=1013358, rating=8.0),
#  Rating(user=1003628, product=1021412, rating=8.0),
#  Rating(user=1003628, product=1235356, rating=8.0),
#  Rating(user=1003637, product=1000699, rating=8.0),
#  Rating(user=1003637, product=2058, rating=8.0),
#  Rating(user=1003637, product=891, rating=8.0),
#  Rating(user=1003642, product=1003594, rating=8.0),
#  Rating(user=1003643, product=1007614, rating=8.0),
#  Rating(user=1003655, product=1002751, rating=8.0),
#  Rating(user=1003655, product=1015844, rating=8.0),
#  Rating(user=1003655, product=1046087, rating=8.0),
#  Rating(user=1003655, product=118, rating=8.0),
#  Rating(user=1003655, product=1258246, rating=8.0),
#  Rating(user=1003655, product=2045391, rating=8.0),
#  Rating(user=1003655, product=4100, rating=8.0),
#  ...]

# %% [markdown]
# **The Alternating Least Squares Algo is popular for recommendation**
#
# Parameters
#
# `rank`
# The number of latent factors in the model
#
# `iterations`
# The number of iterations that the factorization runs
#
# `lambda`
# A standard overfitting parameter. Higher values resist overfitting.

# %%
# Train the ALS model, using seed 314, rank 10, iterations 5, lambda_ 0.01
model = ALS.trainImplicit(trainData, 10, 5, 0.01, seed=314)

# %%
model

# %%
# Model Evaluation

# fetch artists for a test user
testUserID = 1000002

# broadcast artistByID for speed
# [code here]
artistByIDBroadcast = sc.broadcast(artistByID)


# from trainData, collect the artists for the test user. Call the object artistsForUser.
# hint: you will need to apply .value.get(x.product) to the broadcast artistByID, where x is the Rating RDD.
# if you don't do this, you may see artistIDs. you want artist names.

# [code here]
artistsForUser = (trainData
                  .filter(lambda observation: observation.user == testUserID)
                  .map(lambda observation: artistByIDBroadcast.value.get(observation.product))
                  .collect())

# %%
print(artistsForUser)
# Out:
# [u'The Phil Collins Big Band', u'Cream', u'Iron Maiden', u'The Beatles', u'AC/DC', u'Silverchair', u'Warren Bernhardt', u'Helmet', u'The Lightning Seeds', u'Cutting Crew', u'Puddle of Mudd', u'Queens of the Stone Age', u'Soulwax', u'Harvey Danger', u'Duran Duran Feat. Melle Mel &', u'Hootie & the Blowfish', u'18 Wheeler', u'Sleeper', u'Clam Abuse', u'Eiffel 65', u'Eric Burdon & The Animals', u'Carl Douglas', u'Crazy Town', u'Mallrats', u'The Smashing Pumpkins', u'Innerzone Orchestra', u'The Waterboys', u'Procol Harum', u'The Classic Chill Out Album', u'Nat King Cole', u'NoArtist', u'The Goops', u'Rainbow', u'Bentley Ryhthm Ace', u'ZZ Top', u'Bryan Savage', u'Boney James', u'Ken Navarro', u'Keiko Matsui', u'Tuck And Patti', u'Mindi Abair', u'BWB', u'Erroll Garner', u'Jesse Cook', u'Jeff Kashiwa', u'Richard Ashcroft', u'Mr. Big', u'Lakki Patey', u'GRP All-Star Big Band', u'Alex Bugnon', u'Grover Washington Jr.', u'Shakatak', u'Jazzmasters', u'Bona Fide', u'George Howard', u'Mother Love Bone', u'Stanley Clarke', u'Cantaloupe Woman', u'Pimps', u'Yngwie Malmsteen', u'Johnny Fiasco', u'Three Sounds', u'Dropping Bombs On The Whitehouse', u'George Shearing', u'Smith', u'Benny Goodman and His Orchestra', u'Georges Bizet', u'Benny Goodman and Harry James', u'Larry Mullen And Adam Clayton', u'Beth Orton', u'Doves', u'Elvis Presley', u"Sin\xe9ad O'Connor", u'Fr\xe9d\xe9ric Chopin', u'Morcheeba', u'Red Hot Chili Peppers', u'Marvin Gaye', u'Iggy Pop', u'Megadeth', u'George Michael', u'Miles Davis & Marcus Miller', u'Eddie Henderson', u'Julian Cope', u'Suede', u'Electric Wizard', u"Jane's Addiction", u'Phil Collins', u'Chick Corea', u'Baz Luhrmann', u'Fatboy Slim', u'Rob Zombie', u'Ben Harper', u'Backyard Babies', u'Nine Inch Nails', u'Coleman Hawkins']

# %%
# Make 10 recommendations for test user
num_recomm = 10
recommendationsForUser = map(lambda observation: artistByID.get(observation.product), model.call("recommendProducts", testUserID, num_recomm))
print(recommendationsForUser)
# Out:
# [u'Nirvana', u'Metallica', u'The Beatles', u'Nine Inch Nails', u'Pink Floyd', u'Queen', u'Tool', u'Led Zeppelin', u'Red Hot Chili Peppers', u'R.E.M.']

# %%
# Train a second ALS model, same as first but with rank 20
model2 = ALS.trainImplicit(trainData, 20, 5, 0.01, seed=314)

# %%
# Using the rank 20 model, make 10 recommendations for the same test user
recommendationsForUser2 = map(lambda observation: artistByID.get(observation.product), model2.call("recommendProducts", testUserID, num_recomm))
print(recommendationsForUser2)
# Out:
# [u'The Beatles', u'Red Hot Chili Peppers', u'Nine Inch Nails', u'Iron Maiden', u'Queen', u'[unknown]', u'The Smashing Pumpkins', u'The White Stripes', u'Foo Fighters', u'blink-182']
